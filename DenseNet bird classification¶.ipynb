# %% [markdown]
# # DenseNet bird classification

# %% [markdown]
# ## Table of Contents
# * [Introduction](#introduction)
# * [Dataset](#dataset)
# * [Imports](#imports)
# * [Train/Test/Validation split](#train/test/validation-split)
#     * [Dataset merger](#dataset-merger)
#     * [Dataset redistribution](#dataset-redistribution)
# * [Modeling](#modeling)
#     * [Choosing a Model](#choosing-a-model)
#     * [Callbacks](#callbacks)
#     * [Training](#training)
# * [Loading weights](#loading-weights)
# * [Evaluation](#evaluation)
#     * [Predictions](#predictions)
#     * [Metrics](#metrics)
# * [Conclusion](#conclusion)

# %% [markdown]
# <a id="introduction"></a>
# ## Introduction

# %% [markdown]
# Jupyter Notebook explores the application of DenseNet, a powerful convolutional neural network architecture, for multilabel image classification of bird species across 525 unique classes. The core objective is to assess DenseNet's capability in handling datasets with a high degree of variability, showcasing its applicability in classifying bird species with varying appearances, behaviors, and habitats. The dataset comprises 525 bird classes, each with numerous images.
#
# The aim is to leverage DenseNet for its superior performance on large datasets, thanks to its dense connectivity pattern that promotes feature reuse and parameter efficiency.
#
# The methodology involves preprocessing the images, designing the DenseNet model, training it on the dataset, and assessing its performance.

# %% [markdown]
# <a id="dataset"></a>
# ## Dataset

# %% [markdown]
# The dataset used for this project can be found on Kaggle: [BIRDS 525 SPECIES-IMAGE CLASSIFICATION](https://www.kaggle.com/datasets/gpiosenka/100-bird-species)
#
# I selected this one because I wanted to test out the performance of Deep Learning models against a large number of classes (bird species)
#
# Data cleaning is mostly done, and the author has already split dataset into train/test/validation subsets

# %% [markdown]
# <a id="imports"></a>
# ## Imports

# %% [markdown]
# For starters, we need to import the required packages:

# %%
import os
import cv2
import numpy as np
from datetime import datetime

# Modeling
import tensorflow as tf
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.densenet import preprocess_input
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# Metrics
from sklearn.metrics import multilabel_confusion_matrix, classification_report

# Visualisations
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# 2024-06-26 19:47:57.825714: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-26 19:47:58.665633: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-06-26 19:48:00.754847: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-26 19:48:04.556418: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# Settings:

# %%
# Define paths
TRAIN_DIR = 'dataset/train'
VALIDATION_DIR = 'dataset/valid'
TEST_DIR = 'dataset/test'
CHECKPOINTS_DIR = "checkpoints"
LOG_DIR = "logs/fit/" + datetime.now().strftime("%Y%m%d-%H%M%S")  # Logs directory
MODEL_FILEPATH = "checkpoints/model-024-0.526.keras"  # Filepath of the model to load (Not used with weights approach)
MODEL_WEIGHTS = "checkpoints/weights/model.weights.h5"

# Define parameters
IMG_SIZE = (224, 224)
BATCH_SIZE = 16
NUM_CLASSES = len(os.listdir(TRAIN_DIR))
USE_WEIGHTS = True  # Set to true in case of retraining model from weights otherwise false

# %% [markdown]
# and auxiliary functions:

# %%
def preprocessing(image, label):
    """
    Applies preprocessing to an image and returns the processed image along with its label.
    
    return:Processed image and original label.
    """
    image = preprocess_input(image)
    return image, label


def compile_model(start_epoch=0):
    """
    Loads DenseNet121 model, adds custom layers, perform model compile depending on wheather or not you want to use
    weights
    
    return: Compiled model, initial epoch number
    """
    # Load the DenseNet model
    base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    base_model.trainable = False

    # Add custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(1024, activation='relu')(x)
    x = Dropout(0.5)(x)
    predictions = Dense(NUM_CLASSES, activation='softmax')(x)

    # Final model
    model = Model(inputs=base_model.input, outputs=predictions)

    if USE_WEIGHTS is True and os.path.exists(MODEL_WEIGHTS):
        print(f"Weights loading from : {MODEL_WEIGHTS}")
        model.load_weights(MODEL_WEIGHTS)

    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model, start_epoch

def get_class_names(test_dataset):
    """
    Extracts class names from a test dataset.

    return: Class names extracted from the test dataset.
    """
    class_names = test_dataset.class_names
    return class_names


def load_and_preprocess_image(image_path):
    """
    Loads an image from disk, resizes it, expands dimensions, and preprocesses it.

    return: Preprocessed image ready for model input.
    """
    img = cv2.imread(image_path)
    img = cv2.resize(img, IMG_SIZE)  
    img = np.expand_dims(img, axis=0) 
    img = preprocess_input(img)
    return img


def predict_image(image_path, test_dataset):
    """
    Predicts the class of an image using a precompiled model.
    Prints the predicted class name, class index, and prediction accuracy.

    return: None
    """
    # Reconstruct model architecture
    model, start_epoch = compile_model()

    # Load and preprocess the image
    image = load_and_preprocess_image(image_path)

    # Make prediction
    pred = model.predict(image)
    predicted_class = int(np.argmax(pred, axis=1))
    accuracy = np.max(pred)
    class_names = get_class_names(test_dataset)

    # Print the prediction result
    print(f"Predicted Class: {predicted_class}, Class Name: {class_names[predicted_class]}, Accuracy: {accuracy}")

def find_max_fp_fn_class(multiclass_cm, class_names):
    """
    Find the class with the maximum sum of false positives and false negatives.

    return: uple containing the index of the class with the maximum sum of FP+FN,
    and the confusion matrix for that class.
    """
    max_fp_fn_sum = 0
    max_fp_fn_class = None

    for i, cm in enumerate(multiclass_cm):
        fp = cm[0][1]
        fn = cm[1][0]
        total_fp_fn = fp + fn
        
        if total_fp_fn > max_fp_fn_sum:
            max_fp_fn_sum = total_fp_fn
            max_fp_fn_class = i

    result = (max_fp_fn_class,)
    result += (class_names[max_fp_fn_class],)
    
    return result

# %% [markdown]
# <a id="train/test/validation-split"></a>
# ## Train/Test/Validation split

# %% [markdown]
# As the author mentions, the subsets are preselected: "NOTE: The test and validation images in the data set were hand selected to be the "best" images so your model will probably get the highest accuracy score using those data sets versus creating your own test and validation sets. However the latter case is more accurate in terms of model performance on unseen images."
#
# For my purposes, I would like to have a different split ratio; hence, I was using the following scripts to tailor it for my needs.
#
# Additionally, because I don't want it to be executed every time (one is enough to rearrange datasets), I left the code in docstring.

# %% [markdown]
# <a id="dataset-merger"></a>
# ### Dataset-merger

# %% [markdown]
# This script collects data from train / test / valid directories and puts them into a single directory while keeping subdirectory names with labels. It should be used with the dataset_redistribution script to get the data split ratio you want.

# %%
"""
import os
import shutil

source_dirs = ['dataset/train', 'dataset/test', 'dataset/valid']
target_dir = 'converted_dataset'

subdirs = set()

for source_dir in source_dirs:
    for root, dirs, files in os.walk(source_dir):
        for directory in dirs:
            subdirs.add(directory)

for subdir in subdirs:
    # Create the target subdirectory
    target_subdir_path = os.path.join(target_dir, subdir)
    os.makedirs(target_subdir_path, exist_ok=True)

    # Initialize a counter for renaming images
    image_counter = 1

    for source_dir in source_dirs:
        source_subdir_path = os.path.join(source_dir, subdir)
        if os.path.exists(source_subdir_path):
            for file in os.listdir(source_subdir_path):
                if file.endswith('.jpg'):
                    # Construct the full file path
                    source_file_path = os.path.join(source_subdir_path, file)
                    # Construct the new file name
                    new_file_name = f"{image_counter}.jpg"
                    target_file_path = os.path.join(target_subdir_path, new_file_name)
                    # Copy and rename the file
                    shutil.copy(source_file_path, target_file_path)
                    # Increment the counter
                    image_counter += 1

"""

# %% [markdown]
# <a id="dataset-redistribution"></a>
# ### Dataset-redistribution

# %% [markdown]
# After using dataset_merger, we get all the data combined in converted_dataset. This script accesses the said dataset and splits it into a specified ratio

# %%
"""
import splitfolders

# Specify the input folder where your original directories are located
input_folder = "converted_dataset"

# Specify the output folder where you want the split datasets to be saved
output = "dataset"

# Use the split_folders.ratio function to split the dataset
splitfolders.ratio(input_folder, output=output, seed=42, ratio=(0.8, 0.1, 0.1))

"""

# %% [markdown]
# <a id="modeling"></a>
# ## Modeling

# %% [markdown]
# <a id="choosing-a-model"></a>
# ### Choosing a Model

# %% [markdown]
# While in the process of selecting a model initially there were couple considerations among others: EfficientNet, Xception and DenseNet.
#
# This [paper](https://www.mdpi.com/2079-9292/12/14/3132) was a major help in model selection.
#
# Takaways:
#
# * Mobilenet and Resnet were struggling with more difficult dataset
# * While on recommended image size for easy dataset, Mobilenet and Resnet achieved remarkable accuracy. In these ideal scenarios, Densenet followed by Xception performed in very good 98% range
# * On harder dataset, Densenet followed by Xception outperformed Mobilenet and Resnet
# * On smaller image sizes (75x75 which is smaller than models recommended), Densenet and Xception also outperformed the rest
#
# As I wanted to optimize for performance on difficult datasets, ultimately DenseNet was selected

# %% [markdown]
# <a id="callbacks"></a>
# ### Callbacks

# %% [markdown]
# * <b>TensorBoard</b> - Provides us with access to Tensorboard, very useful tool, particularly to analyze loss curves during or after training. With that, I could have information of model performance on train and validation sets.
# * <b>ModelCheckpoint</b> - Works as a safety measure. Each epoch, if the model was improved in terms of a selected metric (validation loss in my case), it saved a model at that point. Model could then be restored in case of some emergency
# * <b>EarlyStopping</b> - To save time and computational power, each time there were no model improvements for prolonged time this callback stops training process
# * <b>ReduceLROnPlateau</b> - Similarly to previous one, if the model was not improving for prolonged time, this callback reduced learning rate. In theory, this allows to train the model some more before it stagnates.
#
#   To prevent training being stopped before learning rate reduced, the ReduceLROnPlateau callback has smaller patience setting (meaning it would trigger before Early stopping)

# %% [markdown]
# <a id="training"></a>
# ### Training

# %% [markdown]
# As the training process is already done by me, and we are going to be loading its results directly as weights, I decided to include code for training I used as a docstring to don't disturb flow of notebook:
#
# Data loading and preprocessing can be seen here:

# %%
"""
# Load and preprocess the training dataset
train_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TRAIN_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int'
)

# Load and preprocess the datasets
validation_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    VALIDATION_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int'
)

# Load and preprocess the test dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False
)

# Apply preprocessing to the training dataset
train_dataset = train_dataset.map(preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
# Apply preprocessing to the validation dataset
validation_dataset = validation_dataset.map(preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
# Apply preprocessing to the test dataset
test_dataset = test_dataset.map(preprocessing, num_parallel_calls=tf.data.AUTOTUNE)
"""

# %% [markdown]
# And training, here:

# %%
"""
# Define callbacks
tensorboard_callback = TensorBoard(log_dir=LOG_DIR, histogram_freq=1)

checkpoint_callback = ModelCheckpoint(filepath=f"{CHECKPOINTS_DIR}/model-{{epoch:03d}}-{{val_loss:.3f}}.keras",
                                      monitor='val_loss',
                                      verbose=1,
                                      save_best_only=True,
                                      mode='auto')

early_stopping_callback = EarlyStopping(monitor="val_loss",
                                        patience=5,
                                        restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor="val_loss",
                              factor=0.2,
                              patience=3,
                              min_lr=1e-6
                              )

# Compile model
model, start_epoch = compile_model()

# Train the model with TensorBoard callback
history = model.fit(train_dataset,
                    epochs=100,
                    validation_data=validation_dataset,
                    callbacks=[tensorboard_callback, checkpoint_callback, early_stopping_callback, reduce_lr],
                    initial_epoch=start_epoch)

# Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f'Test accuracy: {test_acc}, Test loss: {test_loss}')

# Save the model in TensorFlow SavedModel format
model.save('trained_models/data_fixed.keras')
"""

# %% [markdown]
# Assuming training logs are in logs directory, we could just access them in tensorboard to explore training process already done by me.

# %%
# Start tensorboard
# %load_ext tensorboard
# %tensorboard --logdir logs

# %% [markdown]
# Running this as a single training process was impossible for me, because I could not afford to run this on my setup 100% of the time. This can be noted in the different color of the lines on the graph (it counted as a separate run). Each new color line corresponded to me loading the weights and starting where it left off.
#
# Also, the moments at which learning rates were reduced are clearly visible, as well as the positive impact of that callback on overall model performance. The model kept improving for a while after each change except the last one.
#
# Training ended due to model not improving and EarlyStopping callback triggering.

# %% [markdown]
# <b>In case of tensorflow not loading, here are noteworthy graphs in form of image:</b>

# %% [markdown]
# ![Screenshot from 2024-06-21 12-08-53.png](attachment:67aa68e4-6b5b-43aa-9382-f870b74401ad.png)![Screenshot from 2024-06-21 12-08-42.png](attachment:7c4c29d6-830f-430d-914e-f058bdb761e5.png)![Screenshot from 2024-06-21 12-07-57.png](attachment:9b4478ff-581f-4c66-a0cc-9f76c0f9f9a8.png)

# %% [markdown]
# <a id="loading-weights"></a>
# ## Loading weights

# %% [markdown]
# For the purpose of this presentation, let's load the weights from the end of the training process, and work from there. What's important is the  USE_WEIGHTS setting, which should be set to True otherwise it will not load the weights, and we don't want to start training from a scratch.

# %% [markdown]
# <b>We load a test dateset as the other ones were used for training.</b>

# %%
# Load and preprocess the test dataset
test_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    TEST_DIR,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='int',
    shuffle=False
)
# Out:
# Found 9388 files belonging to 526 classes.
# 2024-06-26 19:55:19.496206: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-06-26 19:55:19.672880: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %% [markdown]
# This next block will become useful for predictions, but <b>it is important to get it done before we apply mapping to dataset</b>

# %%
# Initialize an empty list to hold the labels
labels_list = []

# Iterate over the dataset to collect labels
for images, labels in test_dataset:
    labels_list.extend(labels.numpy())

# Get the class names from the test dataset
class_names = test_dataset.class_names
# Out:
# 2024-06-26 19:55:47.630874: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# After that, we proceed as planned with loading weights

# %%
# Apply preprocessing to the test dataset
test_dataset = test_dataset.map(preprocessing, num_parallel_calls=tf.data.AUTOTUNE)

# Reconstruct model architecture
model, start_epoch = compile_model()
# Out:
# Weights loading from : checkpoints/weights/model.weights.h5

# %% [markdown]
# If everything went well, now we have our trained model saved into model and ready for further operations

# %% [markdown]
# <a id="evaluation"></a>
# ### Evaluation

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(test_dataset)
print(f'Test accuracy: {test_acc}, Test loss: {test_loss}')
# Out:
# 2024-06-26 19:56:23.194579: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 51380224 exceeds 10% of free system memory.
# 2024-06-26 19:56:23.513360: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 53231616 exceeds 10% of free system memory.
# 2024-06-26 19:56:23.565920: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 25690112 exceeds 10% of free system memory.
# 2024-06-26 19:56:23.609403: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 19267584 exceeds 10% of free system memory.
# 2024-06-26 19:56:23.613172: W external/local_tsl/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 19267584 exceeds 10% of free system memory.
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 512s 863ms/step - loss: 0.6658 - sparse_categorical_accuracy: 0.8424
# Test accuracy: 0.8567320108413696, Test loss: 0.6019572615623474

# %% [markdown]
# In general for dataset like this I'm content with 85% accuracy. If I were to improve this model further, I would inspect the data for classes that were underperforming. Some other CNN models or different layers could be tested, but in general it's more cost-effective to improve data rather than model.

# %% [markdown]
# <a id="predictions"></a>
# ### Predictions

# %% [markdown]
# Let's see how the model performs on unseen data, following script will show us detection for each image provided in test set:

# %%
pred = model.predict(test_dataset)
pred = np.argmax(pred, axis=1)


positive_count = 0
negative_count = 0

for i, item in enumerate(pred):
    print("Detected: ", item, "-", class_names[item], "True: ", labels_list[i], "-", class_names[labels_list[i]])
    if item == labels_list[i]:
        positive_count += 1
    else:
        negative_count += 1

print(f"Precision: {positive_count/(negative_count+positive_count)}")
# Out:
# 587/587 ━━━━━━━━━━━━━━━━━━━━ 509s 863ms/step
# Detected:  259 - GREATER PEWEE True:  0 - ABBOTTS BABBLER
# Detected:  38 - ASHY THRUSHBIRD True:  0 - ABBOTTS BABBLER
# Detected:  435 - RUFOUS TREPE True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  130 - CAPE ROCK THRUSH True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  347 - MERLIN True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  196 - DUSKY ROBIN True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  0 - ABBOTTS BABBLER True:  0 - ABBOTTS BABBLER
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  404 - RED BILLED TROPICBIRD True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  404 - RED BILLED TROPICBIRD True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  404 - RED BILLED TROPICBIRD True:  1 - ABBOTTS BOOBY
# Detected:  358 - NORTHERN GANNET True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  322 - KOOKABURRA True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  1 - ABBOTTS BOOBY True:  1 - ABBOTTS BOOBY
# Detected:  509 - WHITE CRESTED HORNBILL True:  1 - ABBOTTS BOOBY
# Detected:  390 - POMARINE JAEGER True:  1 - ABBOTTS BOOBY
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  511 - WHITE NECKED RAVEN True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  511 - WHITE NECKED RAVEN True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  2 - ABYSSINIAN GROUND HORNBILL True:  2 - ABYSSINIAN GROUND HORNBILL
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  39 - ASIAN CRESTED IBIS True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  189 - DEMOISELLE CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  3 - AFRICAN CROWNED CRANE True:  3 - AFRICAN CROWNED CRANE
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  111 - BROWN HEADED COWBIRD True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  25 - AMETHYST WOODSTAR True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  496 - VIOLET BACKED STARLING True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  4 - AFRICAN EMERALD CUCKOO True:  4 - AFRICAN EMERALD CUCKOO
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  146 - CHUKAR PARTRIDGE True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  5 - AFRICAN FIREFINCH True:  5 - AFRICAN FIREFINCH
# Detected:  398 - PYRRHULOXIA True:  5 - AFRICAN FIREFINCH
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  6 - AFRICAN OYSTER CATCHER True:  6 - AFRICAN OYSTER CATCHER
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  231 - FRIGATE True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  7 - AFRICAN PIED HORNBILL True:  7 - AFRICAN PIED HORNBILL
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  24 - AMERICAN WIGEON True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  8 - AFRICAN PYGMY GOOSE True:  8 - AFRICAN PYGMY GOOSE
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  310 - JACOBIN PIGEON True:  9 - ALBATROSS
# Detected:  404 - RED BILLED TROPICBIRD True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  344 - MASKED BOOBY True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  401 - RAZORBILL True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  9 - ALBATROSS True:  9 - ALBATROSS
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  412 - RED KNOT True:  10 - ALBERTS TOWHEE
# Detected:  398 - PYRRHULOXIA True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  257 - GREAT TINAMOU True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  289 - HORNED LARK True:  10 - ALBERTS TOWHEE
# Detected:  10 - ALBERTS TOWHEE True:  10 - ALBERTS TOWHEE
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  11 - ALEXANDRINE PARAKEET True:  11 - ALEXANDRINE PARAKEET
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  466 - STRIATED CARACARA True:  12 - ALPINE CHOUGH
# Detected:  484 - TRICOLORED BLACKBIRD True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  12 - ALPINE CHOUGH True:  12 - ALPINE CHOUGH
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  44 - AUSTRAL CANASTERO True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  159 - COMMON IORA True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  522 - YELLOW BREASTED CHAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  57 - BANANAQUIT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  28 - ANDEAN SISKIN True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  13 - ALTAMIRA YELLOWTHROAT
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  165 - CRAB PLOVER True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  14 - AMERICAN AVOCET True:  14 - AMERICAN AVOCET
# Detected:  358 - NORTHERN GANNET True:  14 - AMERICAN AVOCET
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  15 - AMERICAN BITTERN True:  15 - AMERICAN BITTERN
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  16 - AMERICAN COOT True:  16 - AMERICAN COOT
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  97 - BLUE GRAY GNATCATCHER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  17 - AMERICAN DIPPER True:  17 - AMERICAN DIPPER
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  439 - SANDHILL CRANE True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  342 - MARABOU STORK True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  18 - AMERICAN FLAMINGO True:  18 - AMERICAN FLAMINGO
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  30 - ANIANIAU True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  196 - DUSKY ROBIN True:  19 - AMERICAN GOLDFINCH
# Detected:  28 - ANDEAN SISKIN True:  19 - AMERICAN GOLDFINCH
# Detected:  493 - VERDIN True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  225 - FIERY MINIVET True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  159 - COMMON IORA True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  19 - AMERICAN GOLDFINCH True:  19 - AMERICAN GOLDFINCH
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  347 - MERLIN True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  20 - AMERICAN KESTREL True:  20 - AMERICAN KESTREL
# Detected:  416 - RED TAILED HAWK True:  20 - AMERICAN KESTREL
# Detected:  428 - ROUGH LEG BUZZARD True:  20 - AMERICAN KESTREL
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  21 - AMERICAN PIPIT True:  21 - AMERICAN PIPIT
# Detected:  408 - RED FACED WARBLER True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  225 - FIERY MINIVET True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  203 - EASTERN TOWEE True:  22 - AMERICAN REDSTART
# Detected:  362 - NORTHERN PARULA True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  22 - AMERICAN REDSTART True:  22 - AMERICAN REDSTART
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  188 - DAURIAN REDSTART True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  312 - JAPANESE ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  312 - JAPANESE ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  145 - CHUCAO TAPACULO True:  23 - AMERICAN ROBIN
# Detected:  496 - VIOLET BACKED STARLING True:  23 - AMERICAN ROBIN
# Detected:  23 - AMERICAN ROBIN True:  23 - AMERICAN ROBIN
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  479 - TEAL DUCK True:  24 - AMERICAN WIGEON
# Detected:  8 - AFRICAN PYGMY GOOSE True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  52 - BAIKAL TEAL True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  24 - AMERICAN WIGEON True:  24 - AMERICAN WIGEON
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  431 - RUBY THROATED HUMMINGBIRD True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  31 - ANNAS HUMMINGBIRD True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  431 - RUBY THROATED HUMMINGBIRD True:  25 - AMETHYST WOODSTAR
# Detected:  206 - ECUADORIAN HILLSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  25 - AMETHYST WOODSTAR True:  25 - AMETHYST WOODSTAR
# Detected:  450 - SNOW GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  378 - PALM NUT VULTURE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  26 - ANDEAN GOOSE True:  26 - ANDEAN GOOSE
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  345 - MASKED LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  345 - MASKED LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  27 - ANDEAN LAPWING True:  27 - ANDEAN LAPWING
# Detected:  313 - JAVA SPARROW True:  27 - ANDEAN LAPWING
# Detected:  354 - NORTHERN BEARDLESS TYRANNULET True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  196 - DUSKY ROBIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  125 - CANARY True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  291 - HOUSE FINCH True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  125 - CANARY True:  28 - ANDEAN SISKIN
# Detected:  28 - ANDEAN SISKIN True:  28 - ANDEAN SISKIN
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  108 - BRANDT CORMARANT True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  100 - BLUE HERON True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  29 - ANHINGA True:  29 - ANHINGA
# Detected:  240 - GOLDEN BOWER BIRD True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  240 - GOLDEN BOWER BIRD True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  337 - MALAGASY WHITE EYE True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  240 - GOLDEN BOWER BIRD True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  337 - MALAGASY WHITE EYE True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  30 - ANIANIAU True:  30 - ANIANIAU
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  497 - VIOLET CUCKOO True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  431 - RUBY THROATED HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  25 - AMETHYST WOODSTAR True:  31 - ANNAS HUMMINGBIRD
# Detected:  431 - RUBY THROATED HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  431 - RUBY THROATED HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  510 - WHITE EARED HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  31 - ANNAS HUMMINGBIRD True:  31 - ANNAS HUMMINGBIRD
# Detected:  56 - BALTIMORE ORIOLE True:  32 - ANTBIRD
# Detected:  32 - ANTBIRD True:  32 - ANTBIRD
# Detected:  437 - SAMATRAN THRUSH True:  32 - ANTBIRD
# Detected:  113 - BROWN THRASHER True:  32 - ANTBIRD
# Detected:  224 - FASCIATED WREN True:  32 - ANTBIRD
# Detected:  303 - INDIGO FLYCATCHER True:  32 - ANTBIRD
# Detected:  457 - SPANGLED COTINGA True:  32 - ANTBIRD
# Detected:  197 - EARED PITA True:  32 - ANTBIRD
# Detected:  437 - SAMATRAN THRUSH True:  32 - ANTBIRD
# Detected:  145 - CHUCAO TAPACULO True:  32 - ANTBIRD
# Detected:  32 - ANTBIRD True:  32 - ANTBIRD
# Detected:  32 - ANTBIRD True:  32 - ANTBIRD
# Detected:  86 - BLACK THROATED WARBLER True:  32 - ANTBIRD
# Detected:  32 - ANTBIRD True:  32 - ANTBIRD
# Detected:  417 - RED TAILED THRUSH True:  32 - ANTBIRD
# Detected:  32 - ANTBIRD True:  32 - ANTBIRD
# Detected:  140 - CHESTNET BELLIED EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  56 - BALTIMORE ORIOLE True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  205 - EASTERN YELLOW ROBIN True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  33 - ANTILLEAN EUPHONIA True:  33 - ANTILLEAN EUPHONIA
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  443 - SCARLET FACED LIOCICHLA True:  34 - APAPANE
# Detected:  179 - CRIMSON SUNBIRD True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  282 - HEPATIC TANAGER True:  34 - APAPANE
# Detected:  307 - IWI True:  34 - APAPANE
# Detected:  398 - PYRRHULOXIA True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  34 - APAPANE True:  34 - APAPANE
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  109 - BREWERS BLACKBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  196 - DUSKY ROBIN True:  35 - APOSTLEBIRD
# Detected:  441 - SAYS PHOEBE True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  180 - CROW True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  35 - APOSTLEBIRD True:  35 - APOSTLEBIRD
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  36 - ARARIPE MANAKIN True:  36 - ARARIPE MANAKIN
# Detected:  180 - CROW True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  87 - BLACK VENTED SHEARWATER True:  37 - ASHY STORM PETREL
# Detected:  346 - MCKAYS BUNTING True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  158 - COMMON HOUSE MARTIN True:  37 - ASHY STORM PETREL
# Detected:  76 - BLACK COCKATO True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  17 - AMERICAN DIPPER True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  390 - POMARINE JAEGER True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  37 - ASHY STORM PETREL True:  37 - ASHY STORM PETREL
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  224 - FASCIATED WREN True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  145 - CHUCAO TAPACULO True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  155 - COLLARED CRESCENTCHEST True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  518 - WOOD THRUSH True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  374 - OVENBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  38 - ASHY THRUSHBIRD True:  38 - ASHY THRUSHBIRD
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  462 - SQUACCO HERON True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  342 - MARABOU STORK True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  54 - BALD IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  39 - ASIAN CRESTED IBIS True:  39 - ASIAN CRESTED IBIS
# Detected:  77 - BLACK FACED SPOONBILL True:  39 - ASIAN CRESTED IBIS
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  95 - BLUE COAU True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  40 - ASIAN DOLLARD BIRD True:  40 - ASIAN DOLLARD BIRD
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  41 - ASIAN GREEN BEE EATER True:  41 - ASIAN GREEN BEE EATER
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  342 - MARABOU STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  452 - SNOWY EGRET True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  42 - ASIAN OPENBILL STORK True:  42 - ASIAN OPENBILL STORK
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  407 - RED FACED CORMORANT True:  43 - AUCKLAND SHAQ
# Detected:  296 - IMPERIAL SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  296 - IMPERIAL SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  87 - BLACK VENTED SHEARWATER True:  43 - AUCKLAND SHAQ
# Detected:  191 - DOUBLE BRESTED CORMARANT True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  296 - IMPERIAL SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  191 - DOUBLE BRESTED CORMARANT True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  191 - DOUBLE BRESTED CORMARANT True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# Detected:  43 - AUCKLAND SHAQ True:  43 - AUCKLAND SHAQ
# ...
# Detected:  41 - ASIAN GREEN BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  75 - BLACK BREASTED PUFFBIRD True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  513 - WHITE THROATED BEE EATER True:  513 - WHITE THROATED BEE EATER
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  365 - OCELLATED TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  514 - WILD TURKEY True:  514 - WILD TURKEY
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  346 - MCKAYS BUNTING True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  99 - BLUE GROUSE True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  515 - WILLOW PTARMIGAN True:  515 - WILLOW PTARMIGAN
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  516 - WILSONS BIRD OF PARADISE True:  516 - WILSONS BIRD OF PARADISE
# Detected:  479 - TEAL DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  339 - MALLARD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  461 - SPOTTED WHISTLING DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  517 - WOOD DUCK True:  517 - WOOD DUCK
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  374 - OVENBIRD True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  496 - VIOLET BACKED STARLING True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  518 - WOOD THRUSH True:  518 - WOOD THRUSH
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  519 - WOODLAND KINGFISHER True:  519 - WOODLAND KINGFISHER
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  110 - BROWN CREPPER True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  101 - BLUE MALKOHA True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  441 - SAYS PHOEBE True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  520 - WRENTIT True:  520 - WRENTIT
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  205 - EASTERN YELLOW ROBIN True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  523 - YELLOW CACIQUE True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  22 - AMERICAN REDSTART True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  22 - AMERICAN REDSTART True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  362 - NORTHERN PARULA True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  13 - ALTAMIRA YELLOWTHROAT True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  125 - CANARY True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  521 - YELLOW BELLIED FLOWERPECKER
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  205 - EASTERN YELLOW ROBIN True:  522 - YELLOW BREASTED CHAT
# Detected:  57 - BANANAQUIT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  521 - YELLOW BELLIED FLOWERPECKER True:  522 - YELLOW BREASTED CHAT
# Detected:  205 - EASTERN YELLOW ROBIN True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  19 - AMERICAN GOLDFINCH True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  522 - YELLOW BREASTED CHAT True:  522 - YELLOW BREASTED CHAT
# Detected:  174 - CRESTED OROPENDOLA True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  162 - COMMON STARLING True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  523 - YELLOW CACIQUE True:  523 - YELLOW CACIQUE
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  111 - BROWN HEADED COWBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  28 - ANDEAN SISKIN True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  524 - YELLOW HEADED BLACKBIRD True:  524 - YELLOW HEADED BLACKBIRD
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  218 - EUROPEAN TURTLE DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Detected:  525 - ZEBRA DOVE True:  525 - ZEBRA DOVE
# Precision: 0.8567319982956967

# %% [markdown]
# As we can see, it becomes rather tedious to go entry by entry for these predictions. Nevertheless, it is worth to skim through the results to confirm there are no glaring issues with our predictions. We will get more reader friendly data with scikit-learn metrics module next section.

# %% [markdown]
# <a id="metrics"></a>
# ### Metrics

# %% [markdown]
# Let's start with <b>confusion matrix</b>. It will allow us to compare performance of each class. Additionally, I will focus on the ones that are underperforming, as there is more room for improvement there. With custom function, we can see the confusion matrix of a class that has most false positives + false negatives.

# %%
# Compute the multilabel confusion matrix 
mcm = multilabel_confusion_matrix(labels_list, pred)

# Get confussion metric with the worst false positive/negative scores
result = find_max_fp_fn_class(mcm, class_names=class_names)
print(f"Class with maximum FP+FN: {(result)}")
print(mcm[result[0]])
# Out:
# Class with maximum FP+FN: (43, 'AUCKLAND SHAQ')
# [[9356   11]
#  [   9   12]]

# %% [markdown]
# Similarly, we can see metric for each class using <b>classification report</b>. That allows us to pinpoint areas where the model is underperforming and potentially verify/enhance data in that area.

# %%
# Generate the classification report
report = classification_report(labels_list, pred, target_names=class_names)
print(report)
# Out:
#                                precision    recall  f1-score   support
#
#               ABBOTTS BABBLER       0.75      0.67      0.71        18
#                 ABBOTTS BOOBY       0.67      0.63      0.65        19
#    ABYSSINIAN GROUND HORNBILL       0.95      0.90      0.92        20
#         AFRICAN CROWNED CRANE       1.00      0.87      0.93        15
#        AFRICAN EMERALD CUCKOO       0.93      0.82      0.88        17
#             AFRICAN FIREFINCH       0.74      0.88      0.80        16
#        AFRICAN OYSTER CATCHER       1.00      1.00      1.00        17
#         AFRICAN PIED HORNBILL       0.91      0.95      0.93        21
#           AFRICAN PYGMY GOOSE       0.90      0.95      0.93        20
#                     ALBATROSS       0.69      0.73      0.71        15
#                ALBERTS TOWHEE       0.64      0.78      0.70        18
#          ALEXANDRINE PARAKEET       0.95      1.00      0.97        18
#                 ALPINE CHOUGH       0.81      0.89      0.85        19
#         ALTAMIRA YELLOWTHROAT       0.56      0.62      0.59        16
#               AMERICAN AVOCET       1.00      0.90      0.95        20
#              AMERICAN BITTERN       0.95      1.00      0.97        18
#                 AMERICAN COOT       1.00      1.00      1.00        18
#               AMERICAN DIPPER       0.95      0.95      0.95        21
#             AMERICAN FLAMINGO       1.00      0.89      0.94        18
#            AMERICAN GOLDFINCH       0.82      0.60      0.69        15
#              AMERICAN KESTREL       0.88      0.82      0.85        17
#                AMERICAN PIPIT       0.91      1.00      0.95        20
#             AMERICAN REDSTART       0.69      0.69      0.69        16
#                AMERICAN ROBIN       0.80      0.71      0.75        17
#               AMERICAN WIGEON       0.82      0.86      0.84        21
#             AMETHYST WOODSTAR       0.59      0.71      0.65        14
#                  ANDEAN GOOSE       0.87      0.87      0.87        15
#                ANDEAN LAPWING       0.76      0.81      0.79        16
#                 ANDEAN SISKIN       0.67      0.71      0.69        17
#                       ANHINGA       0.79      0.88      0.83        17
#                      ANIANIAU       0.79      0.69      0.73        16
#             ANNAS HUMMINGBIRD       0.59      0.62      0.61        16
#                       ANTBIRD       0.56      0.31      0.40        16
#            ANTILLEAN EUPHONIA       0.62      0.81      0.70        16
#                       APAPANE       0.86      0.71      0.77        17
#                   APOSTLEBIRD       0.68      0.76      0.72        17
#               ARARIPE MANAKIN       1.00      1.00      1.00        17
#             ASHY STORM PETREL       0.61      0.67      0.64        21
#               ASHY THRUSHBIRD       0.81      0.72      0.76        18
#            ASIAN CRESTED IBIS       0.88      0.78      0.82        18
#            ASIAN DOLLARD BIRD       0.88      0.94      0.91        16
#         ASIAN GREEN BEE EATER       0.88      1.00      0.94        23
#          ASIAN OPENBILL STORK       0.95      0.90      0.92        20
#                 AUCKLAND SHAQ       0.52      0.57      0.55        21
#             AUSTRAL CANASTERO       0.85      0.65      0.73        17
#          AUSTRALASIAN FIGBIRD       0.79      0.75      0.77        20
#                      AVADAVAT       0.88      0.83      0.86        18
#              AZARAS SPINETAIL       0.72      0.68      0.70        19
#          AZURE BREASTED PITTA       0.94      0.94      0.94        16
#                     AZURE JAY       0.69      0.69      0.69        16
#                 AZURE TANAGER       1.00      0.75      0.86        16
#                     AZURE TIT       0.93      0.78      0.85        18
#                   BAIKAL TEAL       0.71      0.75      0.73        16
#                    BALD EAGLE       0.89      1.00      0.94        17
#                     BALD IBIS       0.94      0.88      0.91        17
#                 BALI STARLING       1.00      0.87      0.93        15
#              BALTIMORE ORIOLE       0.77      0.62      0.69        16
#                    BANANAQUIT       0.67      0.56      0.61        18
#              BAND TAILED GUAN       0.82      0.78      0.80        18
#              BANDED BROADBILL       0.91      0.95      0.93        21
#                   BANDED PITA       0.90      1.00      0.95        19
#                  BANDED STILT       0.93      0.76      0.84        17
#             BAR-TAILED GODWIT       1.00      0.95      0.97        19
#                      BARN OWL       1.00      0.94      0.97        18
#                  BARN SWALLOW       1.00      0.80      0.89        15
#               BARRED PUFFBIRD       0.69      0.69      0.69        16
#             BARROWS GOLDENEYE       0.92      0.73      0.81        15
#          BAY-BREASTED WARBLER       0.81      0.81      0.81        16
#                BEARDED BARBET       0.94      0.88      0.91        17
#              BEARDED BELLBIRD       0.94      1.00      0.97        16
#              BEARDED REEDLING       1.00      0.94      0.97        16
#             BELTED KINGFISHER       1.00      0.94      0.97        17
#              BIRD OF PARADISE       0.76      0.94      0.84        17
#    BLACK AND YELLOW BROADBILL       0.94      1.00      0.97        16
#                    BLACK BAZA       0.82      1.00      0.90        18
#       BLACK BREASTED PUFFBIRD       0.88      0.79      0.83        19
#                 BLACK COCKATO       0.75      0.80      0.77        15
#         BLACK FACED SPOONBILL       0.73      0.89      0.80        18
#               BLACK FRANCOLIN       0.59      0.67      0.62        15
#           BLACK HEADED CAIQUE       1.00      0.95      0.97        20
#            BLACK NECKED STILT       0.84      0.84      0.84        19
#                 BLACK SKIMMER       0.93      0.82      0.88        17
#                    BLACK SWAN       1.00      0.94      0.97        18
#              BLACK TAIL CRAKE       1.00      1.00      1.00        18
#        BLACK THROATED BUSHTIT       0.94      0.89      0.91        18
#           BLACK THROATED HUET       0.93      0.88      0.90        16
#        BLACK THROATED WARBLER       0.69      0.73      0.71        15
#       BLACK VENTED SHEARWATER       0.79      0.71      0.75        21
#                 BLACK VULTURE       0.89      0.94      0.92        18
#        BLACK-CAPPED CHICKADEE       0.94      1.00      0.97        15
#            BLACK-NECKED GREBE       0.93      0.88      0.90        16
#        BLACK-THROATED SPARROW       0.71      0.89      0.79        19
#          BLACKBURNIAM WARBLER       0.88      0.93      0.90        15
#     BLONDE CRESTED WOODPECKER       0.87      0.81      0.84        16
#                BLOOD PHEASANT       1.00      0.94      0.97        17
#                     BLUE COAU       0.62      0.59      0.61        17
#                   BLUE DACNIS       0.79      0.79      0.79        19
#         BLUE GRAY GNATCATCHER       0.73      0.90      0.81        21
#                 BLUE GROSBEAK       0.94      0.83      0.88        18
#                   BLUE GROUSE       0.67      0.90      0.77        20
#                    BLUE HERON       0.76      0.84      0.80        19
#                  BLUE MALKOHA       0.67      0.76      0.71        21
#     BLUE THROATED PIPING GUAN       0.83      0.91      0.87        22
#        BLUE THROATED TOUCANET       1.00      0.88      0.93        16
#                      BOBOLINK       0.80      0.89      0.84        18
#           BORNEAN BRISTLEHEAD       1.00      0.71      0.83        17
#              BORNEAN LEAFBIRD       0.71      0.71      0.71        17
#              BORNEAN PHEASANT       0.87      0.76      0.81        17
#              BRANDT CORMARANT       0.70      0.94      0.80        17
#             BREWERS BLACKBIRD       0.55      0.55      0.55        20
#                 BROWN CREPPER       0.88      0.70      0.78        20
#          BROWN HEADED COWBIRD       0.71      0.71      0.71        21
#                   BROWN NOODY       0.92      0.65      0.76        17
#                BROWN THRASHER       0.85      0.94      0.89        18
#                    BUFFLEHEAD       0.76      0.95      0.84        20
#              BULWERS PHEASANT       0.93      0.76      0.84        17
#             BURCHELLS COURSER       0.93      0.88      0.90        16
#                   BUSH TURKEY       1.00      0.88      0.94        17
#            CAATINGA CACHOLOTE       0.79      0.88      0.83        17
#               CABOTS TRAGOPAN       0.75      0.90      0.82        20
#                   CACTUS WREN       0.76      0.89      0.82        18
#             CALIFORNIA CONDOR       0.89      0.94      0.91        17
#               CALIFORNIA GULL       0.81      0.76      0.79        17
#              CALIFORNIA QUAIL       1.00      0.83      0.91        18
#                 CAMPO FLICKER       1.00      1.00      1.00        22
#                        CANARY       0.60      0.71      0.65        17
#                    CANVASBACK       0.85      0.85      0.85        20
#          CAPE GLOSSY STARLING       0.94      1.00      0.97        17
#                 CAPE LONGCLAW       0.87      0.87      0.87        15
#              CAPE MAY WARBLER       0.67      0.71      0.69        17
#              CAPE ROCK THRUSH       0.80      0.94      0.86        17
#                  CAPPED HERON       1.00      0.94      0.97        16
#                  CAPUCHINBIRD       0.92      0.80      0.86        15
#             CARMINE BEE-EATER       0.89      0.94      0.92        18
#                  CASPIAN TERN       0.87      0.87      0.87        23
#                     CASSOWARY       1.00      0.88      0.94        17
#                 CEDAR WAXWING       0.94      0.84      0.89        19
#              CERULEAN WARBLER       0.89      0.89      0.89        18
#               CHARA DE COLLAR       0.76      0.76      0.76        17
#               CHATTERING LORY       1.00      1.00      1.00        16
#     CHESTNET BELLIED EUPHONIA       0.86      0.80      0.83        15
#        CHESTNUT WINGED CUCKOO       0.80      0.89      0.84        18
#      CHINESE BAMBOO PARTRIDGE       0.94      0.94      0.94        18
#            CHINESE POND HERON       0.91      0.62      0.74        16
#              CHIPPING SPARROW       0.86      1.00      0.92        18
#               CHUCAO TAPACULO       0.72      0.81      0.76        16
#              CHUKAR PARTRIDGE       0.95      0.95      0.95        19
#               CINNAMON ATTILA       0.80      0.89      0.84        18
#           CINNAMON FLYCATCHER       0.79      0.83      0.81        18
#                 CINNAMON TEAL       0.74      0.78      0.76        18
#                  CLARKS GREBE       0.95      0.90      0.92        20
#             CLARKS NUTCRACKER       0.89      0.94      0.92        18
#             COCK OF THE  ROCK       0.95      1.00      0.97        18
#                      COCKATOO       1.00      1.00      1.00        19
#              COLLARED ARACARI       0.95      0.90      0.92        20
#        COLLARED CRESCENTCHEST       0.76      0.84      0.80        19
#              COMMON FIRECREST       0.88      0.88      0.88        16
#                COMMON GRACKLE       0.71      0.75      0.73        20
#           COMMON HOUSE MARTIN       0.68      0.72      0.70        18
#                   COMMON IORA       0.58      0.47      0.52        15
#                   COMMON LOON       1.00      0.78      0.88        18
#               COMMON POORWILL       0.79      0.83      0.81        18
#               COMMON STARLING       0.75      0.94      0.83        16
#            COPPERSMITH BARBET       0.96      1.00      0.98        22
#         COPPERY TAILED COUCAL       0.88      0.94      0.91        16
#                   CRAB PLOVER       0.89      1.00      0.94        16
#                    CRANE HAWK       0.67      0.40      0.50        15
#      CREAM COLORED WOODPECKER       0.94      0.94      0.94        16
#                CRESTED AUKLET       0.94      0.88      0.91        17
#              CRESTED CARACARA       1.00      0.94      0.97        17
#                  CRESTED COUA       0.75      0.71      0.73        17
#              CRESTED FIREBACK       0.88      0.88      0.88        16
#            CRESTED KINGFISHER       1.00      0.94      0.97        18
#              CRESTED NUTHATCH       0.88      0.88      0.88        17
#            CRESTED OROPENDOLA       0.70      0.78      0.74        18
#         CRESTED SERPENT EAGLE       0.81      0.85      0.83        20
#             CRESTED SHRIKETIT       0.93      0.78      0.85        18
#        CRESTED WOOD PARTRIDGE       1.00      0.95      0.98        22
#                  CRIMSON CHAT       0.88      0.88      0.88        17
#               CRIMSON SUNBIRD       0.91      0.91      0.91        22
#                          CROW       0.70      0.78      0.74        18
#                    CUBAN TODY       0.94      0.94      0.94        18
#                  CUBAN TROGON       0.88      0.88      0.88        16
#          CURL CRESTED ARACURI       0.93      0.81      0.87        16
#              D-ARNAUDS BARBET       0.91      0.80      0.85        25
#             DALMATIAN PELICAN       1.00      0.78      0.88        18
#         DARJEELING WOODPECKER       0.93      0.81      0.87        16
#               DARK EYED JUNCO       0.95      0.95      0.95        22
#              DAURIAN REDSTART       0.78      0.82      0.80        17
#              DEMOISELLE CRANE       0.94      1.00      0.97        16
#           DOUBLE BARRED FINCH       1.00      1.00      1.00        17
#      DOUBLE BRESTED CORMARANT       0.70      0.80      0.74        20
#        DOUBLE EYED FIG PARROT       0.81      0.89      0.85        19
#              DOWNY WOODPECKER       0.89      0.94      0.92        18
#                        DUNLIN       0.87      1.00      0.93        20
#                    DUSKY LORY       1.00      1.00      1.00        16
#                   DUSKY ROBIN       0.67      0.93      0.78        15
#                    EARED PITA       0.94      0.94      0.94        17
#              EASTERN BLUEBIRD       0.89      1.00      0.94        17
#            EASTERN BLUEBONNET       1.00      0.87      0.93        15
#         EASTERN GOLDEN WEAVER       0.65      0.76      0.70        17
#            EASTERN MEADOWLARK       0.95      0.95      0.95        20
#               EASTERN ROSELLA       0.89      0.94      0.91        17
#                 EASTERN TOWEE       0.78      0.78      0.78        18
#         EASTERN WIP POOR WILL       0.80      0.75      0.77        16
#          EASTERN YELLOW ROBIN       0.67      0.82      0.73        22
#           ECUADORIAN HILLSTAR       0.86      0.75      0.80        16
#                EGYPTIAN GOOSE       0.94      0.83      0.88        18
#                ELEGANT TROGON       0.94      0.94      0.94        16
#             ELLIOTS  PHEASANT       0.89      0.89      0.89        18
#               EMERALD TANAGER       0.81      0.81      0.81        16
#               EMPEROR PENGUIN       1.00      0.94      0.97        17
#                           EMU       0.95      1.00      0.97        18
#                  ENGGANO MYNA       0.81      0.72      0.76        18
#            EURASIAN BULLFINCH       0.90      1.00      0.95        19
#        EURASIAN GOLDEN ORIOLE       0.89      0.57      0.70        14
#               EURASIAN MAGPIE       0.83      0.88      0.86        17
#            EUROPEAN GOLDFINCH       1.00      0.93      0.97        15
#          EUROPEAN TURTLE DOVE       0.93      0.81      0.87        16
#              EVENING GROSBEAK       0.88      0.94      0.91        16
#                FAIRY BLUEBIRD       0.84      0.94      0.89        17
#                 FAIRY PENGUIN       0.93      0.82      0.88        17
#                    FAIRY TERN       0.86      0.75      0.80        16
#              FAN TAILED WIDOW       0.67      0.50      0.57        16
#                FASCIATED WREN       0.69      0.69      0.69        16
#                 FIERY MINIVET       0.73      0.69      0.71        16
#             FIORDLAND PENGUIN       0.94      0.94      0.94        17
#         FIRE TAILLED MYZORNIS       0.88      0.94      0.91        16
#               FLAME BOWERBIRD       1.00      0.83      0.91        18
#                 FLAME TANAGER       0.88      0.70      0.78        20
#                FOREST WAGTAIL       0.89      0.89      0.89        19
#                       FRIGATE       0.86      0.67      0.75        18
#             FRILL BACK PIGEON       0.91      0.91      0.91        23
#                 GAMBELS QUAIL       0.84      0.94      0.89        17
#            GANG GANG COCKATOO       1.00      0.94      0.97        16
#               GILA WOODPECKER       0.88      0.88      0.88        17
#                GILDED FLICKER       0.79      0.69      0.73        16
#                   GLOSSY IBIS       1.00      0.95      0.97        19
#                  GO AWAY BIRD       0.73      0.53      0.62        15
#             GOLD WING WARBLER       0.94      0.83      0.88        18
#             GOLDEN BOWER BIRD       0.64      0.93      0.76        15
#        GOLDEN CHEEKED WARBLER       0.89      0.85      0.87        20
#           GOLDEN CHLOROPHONIA       0.76      0.87      0.81        15
#                  GOLDEN EAGLE       0.82      0.78      0.80        18
#               GOLDEN PARAKEET       0.94      0.94      0.94        16
#               GOLDEN PHEASANT       1.00      1.00      1.00        18
#                  GOLDEN PIPIT       0.89      0.89      0.89        18
#                GOULDIAN FINCH       0.80      0.94      0.86        17
#                      GRANDALA       1.00      0.82      0.90        17
#                  GRAY CATBIRD       0.81      1.00      0.89        17
#                 GRAY KINGBIRD       0.67      0.78      0.72        18
#                GRAY PARTRIDGE       0.80      0.94      0.86        17
#                   GREAT ARGUS       0.86      0.90      0.88        21
#                GREAT GRAY OWL       0.88      0.88      0.88        16
#                 GREAT JACAMAR       1.00      0.89      0.94        18
#                GREAT KISKADEE       0.90      0.95      0.92        19
#                   GREAT POTOO       0.70      0.88      0.78        16
#                 GREAT TINAMOU       0.89      0.89      0.89        18
#                  GREAT XENOPS       0.65      0.65      0.65        17
#                 GREATER PEWEE       0.56      0.78      0.65        18
#       GREATER PRAIRIE CHICKEN       0.95      0.91      0.93        22
#           GREATOR SAGE GROUSE       0.95      0.90      0.92        20
#               GREEN BROADBILL       1.00      0.93      0.97        15
#                     GREEN JAY       0.94      0.83      0.88        18
#                  GREEN MAGPIE       0.95      0.90      0.92        20
#             GREEN WINGED DOVE       0.94      0.94      0.94        17
#             GREY CUCKOOSHRIKE       0.80      0.67      0.73        18
#        GREY HEADED CHACHALACA       0.87      0.91      0.89        22
#        GREY HEADED FISH EAGLE       0.64      0.56      0.60        16
#                   GREY PLOVER       0.94      0.83      0.88        18
#             GROVED BILLED ANI       0.76      0.76      0.76        17
#                 GUINEA TURACO       0.93      0.72      0.81        18
#                    GUINEAFOWL       0.93      0.88      0.90        16
#                 GURNEYS PITTA       1.00      0.89      0.94        18
#                     GYRFALCON       0.62      0.72      0.67        18
#                      HAMERKOP       1.00      0.89      0.94        18
#                HARLEQUIN DUCK       0.94      1.00      0.97        17
#               HARLEQUIN QUAIL       0.81      0.87      0.84        15
#                   HARPY EAGLE       0.89      0.84      0.86        19
#                HAWAIIAN GOOSE       0.89      1.00      0.94        17
#                      HAWFINCH       0.85      0.89      0.87        19
#                  HELMET VANGA       0.89      1.00      0.94        17
#               HEPATIC TANAGER       0.73      0.47      0.57        17
#            HIMALAYAN BLUETAIL       0.82      0.88      0.85        16
#               HIMALAYAN MONAL       0.94      1.00      0.97        17
#                       HOATZIN       0.94      1.00      0.97        17
#              HOODED MERGANSER       1.00      0.73      0.85        15
#                       HOOPOES       0.94      1.00      0.97        17
#                   HORNED GUAN       0.94      0.94      0.94        18
#                   HORNED LARK       0.83      1.00      0.90        19
#                 HORNED SUNGEM       0.84      0.94      0.89        17
#                   HOUSE FINCH       0.74      0.85      0.79        27
#                 HOUSE SPARROW       0.93      0.82      0.88        17
#                HYACINTH MACAW       1.00      1.00      1.00        18
#                IBERIAN MAGPIE       0.81      0.94      0.87        18
#                      IBISBILL       1.00      0.94      0.97        16
#                 IMPERIAL SHAQ       0.62      0.50      0.55        16
#                     INCA TERN       1.00      0.94      0.97        18
#                INDIAN BUSTARD       0.94      1.00      0.97        15
#                  INDIAN PITTA       0.95      0.90      0.93        21
#                 INDIAN ROLLER       0.87      1.00      0.93        20
#                INDIAN VULTURE       0.74      0.88      0.80        16
#                INDIGO BUNTING       0.87      0.76      0.81        17
#             INDIGO FLYCATCHER       0.94      0.88      0.91        17
#               INLAND DOTTEREL       0.85      0.94      0.89        18
#          IVORY BILLED ARACARI       0.94      0.94      0.94        17
#                    IVORY GULL       0.94      0.94      0.94        18
#                           IWI       0.94      0.94      0.94        17
#                        JABIRU       0.94      0.94      0.94        16
#                    JACK SNIPE       1.00      0.94      0.97        18
#                JACOBIN PIGEON       0.70      0.86      0.78        22
#              JANDAYA PARAKEET       1.00      0.94      0.97        18
#                JAPANESE ROBIN       0.82      1.00      0.90        18
#                  JAVA SPARROW       0.86      1.00      0.92        18
#             JOCOTOCO ANTPITTA       0.90      1.00      0.95        18
#                          KAGU       0.94      0.94      0.94        16
#                        KAKAPO       1.00      1.00      1.00        17
#                      KILLDEAR       0.94      0.79      0.86        19
#                    KING EIDER       0.95      1.00      0.97        18
#                  KING VULTURE       0.94      0.94      0.94        16
#                          KIWI       1.00      1.00      1.00        16
#              KNOB BILLED DUCK       0.91      0.91      0.91        22
#                    KOOKABURRA       0.94      1.00      0.97        16
#                  LARK BUNTING       0.78      0.82      0.80        17
#                 LAUGHING GULL       0.80      0.87      0.83        23
#                LAZULI BUNTING       1.00      0.94      0.97        18
#               LESSER ADJUTANT       0.92      0.65      0.76        17
#                  LILAC ROLLER       0.87      0.81      0.84        16
#                       LIMPKIN       0.95      1.00      0.98        21
#                    LITTLE AUK       0.83      0.79      0.81        19
#             LOGGERHEAD SHRIKE       0.59      0.95      0.73        20
#                LONG-EARED OWL       0.88      0.82      0.85        17
#                  LOONEY BIRDS       0.95      1.00      0.97        18
#           LUCIFER HUMMINGBIRD       0.93      0.68      0.79        19
#                  MAGPIE GOOSE       0.94      1.00      0.97        16
#              MALABAR HORNBILL       0.83      0.88      0.86        17
#          MALACHITE KINGFISHER       0.88      0.83      0.86        18
#            MALAGASY WHITE EYE       0.75      0.75      0.75        16
#                         MALEO       1.00      0.94      0.97        18
#                  MALLARD DUCK       0.86      0.80      0.83        15
#                  MANDRIN DUCK       1.00      1.00      1.00        17
#               MANGROVE CUCKOO       0.92      0.75      0.83        16
#                 MARABOU STORK       0.72      0.95      0.82        22
#               MASKED BOBWHITE       0.94      0.80      0.86        20
#                  MASKED BOOBY       0.77      0.67      0.71        15
#                MASKED LAPWING       0.75      0.80      0.77        15
#                MCKAYS BUNTING       0.79      0.90      0.84        21
#                        MERLIN       0.64      0.78      0.71        23
#              MIKADO  PHEASANT       0.85      1.00      0.92        17
#                MILITARY MACAW       0.95      0.87      0.91        23
#                 MOURNING DOVE       0.94      0.94      0.94        17
#                          MYNA       1.00      0.81      0.90        16
#                NICOBAR PIGEON       1.00      0.94      0.97        17
#               NOISY FRIARBIRD       0.78      0.78      0.78        18
# NORTHERN BEARDLESS TYRANNULET       0.71      0.60      0.65        20
#             NORTHERN CARDINAL       0.94      0.94      0.94        17
#              NORTHERN FLICKER       0.67      0.62      0.65        16
#               NORTHERN FULMAR       0.90      0.56      0.69        16
#               NORTHERN GANNET       0.74      0.82      0.78        17
#              NORTHERN GOSHAWK       0.65      0.65      0.65        17
#               NORTHERN JACANA       0.93      0.72      0.81        18
#          NORTHERN MOCKINGBIRD       0.78      0.93      0.85        15
#               NORTHERN PARULA       0.83      0.86      0.84        22
#           NORTHERN RED BISHOP       0.80      0.86      0.83        14
#             NORTHERN SHOVELER       1.00      1.00      1.00        17
#              OCELLATED TURKEY       0.95      1.00      0.97        18
#                       OILBIRD       0.94      0.80      0.86        20
#                  OKINAWA RAIL       0.94      0.94      0.94        17
#        ORANGE BREASTED TROGON       0.90      0.90      0.90        21
#        ORANGE BRESTED BUNTING       0.79      0.73      0.76        15
#              ORIENTAL BAY OWL       0.94      0.94      0.94        18
#             ORNATE HAWK EAGLE       0.89      0.74      0.81        23
#                        OSPREY       0.67      0.59      0.62        17
#                       OSTRICH       0.85      0.94      0.89        18
#                      OVENBIRD       0.92      0.92      0.92        25
#                OYSTER CATCHER       0.96      1.00      0.98        23
#               PAINTED BUNTING       1.00      0.94      0.97        18
#                        PALILA       0.94      0.88      0.91        17
#              PALM NUT VULTURE       0.83      0.90      0.86        21
#              PARADISE TANAGER       0.89      0.80      0.84        20
#              PARAKETT  AUKLET       0.88      0.88      0.88        16
#               PARAKETT AUKLET       0.00      0.00      0.00         1
#                   PARUS MAJOR       0.94      0.94      0.94        18
#       PATAGONIAN SIERRA FINCH       0.91      0.71      0.80        14
#                       PEACOCK       1.00      1.00      1.00        18
#              PEREGRINE FALCON       0.78      0.78      0.78        18
#                   PHAINOPEPLA       1.00      0.81      0.89        21
#              PHILIPPINE EAGLE       0.94      1.00      0.97        17
#                    PINK ROBIN       1.00      1.00      1.00        17
#             PLUSH CRESTED JAY       0.91      0.95      0.93        21
#               POMARINE JAEGER       0.42      0.73      0.54        15
#                        PUFFIN       1.00      0.95      0.97        19
#                     PUNA TEAL       0.89      0.85      0.87        20
#                  PURPLE FINCH       0.93      0.76      0.84        17
#              PURPLE GALLINULE       0.93      0.82      0.88        17
#                 PURPLE MARTIN       0.79      0.65      0.71        17
#               PURPLE SWAMPHEN       0.89      0.94      0.91        17
#              PYGMY KINGFISHER       0.79      0.79      0.79        19
#                   PYRRHULOXIA       0.79      0.83      0.81        23
#                       QUETZAL       0.94      0.94      0.94        17
#              RAINBOW LORIKEET       1.00      1.00      1.00        15
#                     RAZORBILL       0.80      0.76      0.78        21
#         RED BEARDED BEE EATER       1.00      0.95      0.98        22
#             RED BELLIED PITTA       1.00      0.82      0.90        17
#         RED BILLED TROPICBIRD       0.66      0.91      0.76        23
#              RED BROWED FINCH       0.93      0.88      0.90        16
#                 RED CROSSBILL       0.88      0.71      0.79        21
#           RED FACED CORMORANT       0.75      0.71      0.73        17
#             RED FACED WARBLER       0.94      0.89      0.92        19
#                      RED FODY       0.89      0.89      0.89        19
#               RED HEADED DUCK       0.81      0.76      0.79        17
#         RED HEADED WOODPECKER       0.87      0.87      0.87        15
#                      RED KNOT       0.82      0.86      0.84        21
#       RED LEGGED HONEYCREEPER       0.83      0.79      0.81        19
#              RED NAPED TROGON       0.77      0.94      0.85        18
#           RED SHOULDERED HAWK       0.87      0.68      0.76        19
#               RED TAILED HAWK       0.55      0.73      0.63        22
#             RED TAILED THRUSH       0.93      0.93      0.93        14
#          RED WINGED BLACKBIRD       0.70      0.41      0.52        17
#           RED WISKERED BULBUL       0.89      0.94      0.92        18
#              REGENT BOWERBIRD       0.94      0.94      0.94        18
#          RING-NECKED PHEASANT       0.93      0.82      0.88        17
#                    ROADRUNNER       1.00      1.00      1.00        17
#                     ROCK DOVE       1.00      0.80      0.89        15
#        ROSE BREASTED COCKATOO       1.00      1.00      1.00        22
#        ROSE BREASTED GROSBEAK       0.81      0.89      0.85        19
#             ROSEATE SPOONBILL       1.00      0.90      0.95        21
#           ROSY FACED LOVEBIRD       0.94      1.00      0.97        16
#             ROUGH LEG BUZZARD       0.64      0.53      0.58        17
#              ROYAL FLYCATCHER       0.94      0.94      0.94        16
#          RUBY CROWNED KINGLET       0.76      0.76      0.76        21
#     RUBY THROATED HUMMINGBIRD       0.62      0.67      0.65        15
#                RUDDY SHELDUCK       1.00      0.94      0.97        18
#               RUDY KINGFISHER       0.85      1.00      0.92        17
#             RUFOUS KINGFISHER       0.94      0.89      0.91        18
#                  RUFOUS TREPE       0.80      0.86      0.83        28
#                 RUFUOS MOTMOT       0.86      0.90      0.88        21
#               SAMATRAN THRUSH       0.77      1.00      0.87        17
#                   SAND MARTIN       0.73      0.65      0.69        17
#                SANDHILL CRANE       0.80      0.89      0.84        18
#                SATYR TRAGOPAN       1.00      0.89      0.94        19
#                   SAYS PHOEBE       0.75      0.68      0.71        22
#    SCARLET CROWNED FRUIT DOVE       0.80      0.94      0.86        17
#       SCARLET FACED LIOCICHLA       0.83      0.88      0.86        17
#                  SCARLET IBIS       1.00      1.00      1.00        16
#                 SCARLET MACAW       0.95      1.00      0.97        18
#               SCARLET TANAGER       0.93      0.93      0.93        15
#                      SHOEBILL       0.94      0.89      0.92        19
#        SHORT BILLED DOWITCHER       0.89      0.94      0.92        18
#               SMITHS LONGSPUR       1.00      0.65      0.79        17
#                    SNOW GOOSE       0.77      0.85      0.81        20
#                SNOW PARTRIDGE       0.67      0.74      0.70        19
#                   SNOWY EGRET       0.88      1.00      0.94        15
#                     SNOWY OWL       0.94      0.94      0.94        18
#                  SNOWY PLOVER       0.85      0.79      0.81        14
#              SNOWY SHEATHBILL       0.86      0.90      0.88        21
#                          SORA       0.90      0.90      0.90        21
#              SPANGLED COTINGA       0.81      0.76      0.79        17
#                 SPLENDID WREN       1.00      0.83      0.91        18
#         SPOON BILED SANDPIPER       1.00      0.88      0.93        16
#               SPOTTED CATBIRD       0.84      1.00      0.91        16
#        SPOTTED WHISTLING DUCK       0.78      0.70      0.74        20
#                 SQUACCO HERON       0.79      0.88      0.83        17
#         SRI LANKA BLUE MAGPIE       1.00      0.89      0.94        18
#                  STEAMER DUCK       0.94      1.00      0.97        17
#       STORK BILLED KINGFISHER       0.93      0.87      0.90        15
#             STRIATED CARACARA       0.90      0.86      0.88        22
#                   STRIPED OWL       0.82      0.88      0.85        16
#              STRIPPED MANAKIN       1.00      1.00      1.00        16
#              STRIPPED SWALLOW       0.89      1.00      0.94        17
#                    SUNBITTERN       0.81      0.89      0.85        19
#               SUPERB STARLING       1.00      0.94      0.97        17
#                   SURF SCOTER       0.91      1.00      0.95        20
#             SWINHOES PHEASANT       0.88      0.92      0.90        24
#                    TAILORBIRD       0.87      0.81      0.84        16
#                 TAIWAN MAGPIE       0.94      0.94      0.94        16
#                        TAKAHE       0.89      0.94      0.92        18
#                 TASMANIAN HEN       0.88      0.93      0.90        15
#               TAWNY FROGMOUTH       0.82      0.86      0.84        21
#                     TEAL DUCK       0.71      0.59      0.65        17
#                     TIT MOUSE       1.00      0.82      0.90        17
#                       TOUCHAN       1.00      1.00      1.00        16
#             TOWNSENDS WARBLER       0.67      0.67      0.67        18
#                  TREE SWALLOW       0.80      0.80      0.80        20
#          TRICOLORED BLACKBIRD       0.56      0.56      0.56        16
#             TROPICAL KINGBIRD       0.94      0.88      0.91        17
#                 TRUMPTER SWAN       1.00      1.00      1.00        16
#                TURKEY VULTURE       0.94      0.89      0.91        18
#              TURQUOISE MOTMOT       0.84      0.89      0.86        18
#                 UMBRELLA BIRD       0.88      0.88      0.88        17
#                 VARIED THRUSH       0.86      0.90      0.88        21
#                         VEERY       0.95      0.95      0.95        20
#          VENEZUELIAN TROUPIAL       0.83      0.88      0.86        17
#                        VERDIN       0.86      0.95      0.90        20
#           VERMILION FLYCATHER       0.82      0.82      0.82        17
#       VICTORIA CROWNED PIGEON       1.00      1.00      1.00        17
#        VIOLET BACKED STARLING       0.83      0.68      0.75        22
#                 VIOLET CUCKOO       0.83      1.00      0.90        19
#          VIOLET GREEN SWALLOW       0.87      0.91      0.89        22
#                 VIOLET TURACO       1.00      0.94      0.97        18
#              VISAYAN HORNBILL       1.00      0.72      0.84        18
#          VULTURINE GUINEAFOWL       0.86      0.95      0.90        19
#                  WALL CREAPER       0.94      0.89      0.92        19
#              WATTLED CURASSOW       0.83      0.94      0.88        16
#               WATTLED LAPWING       0.82      0.88      0.85        16
#                      WHIMBREL       0.93      0.88      0.90        16
#       WHITE BREASTED WATERHEN       0.94      0.83      0.88        18
#            WHITE BROWED CRAKE       0.79      0.88      0.83        17
#          WHITE CHEEKED TURACO       0.83      0.88      0.86        17
#        WHITE CRESTED HORNBILL       0.81      0.94      0.87        18
#       WHITE EARED HUMMINGBIRD       0.90      0.90      0.90        20
#            WHITE NECKED RAVEN       0.75      0.71      0.73        17
#           WHITE TAILED TROPIC       0.72      0.68      0.70        19
#      WHITE THROATED BEE EATER       0.88      0.83      0.86        18
#                   WILD TURKEY       0.89      0.94      0.91        17
#              WILLOW PTARMIGAN       0.95      0.90      0.93        21
#      WILSONS BIRD OF PARADISE       0.94      1.00      0.97        17
#                     WOOD DUCK       1.00      0.87      0.93        23
#                   WOOD THRUSH       0.91      0.91      0.91        23
#           WOODLAND KINGFISHER       1.00      1.00      1.00        21
#                       WRENTIT       0.90      0.86      0.88        21
#   YELLOW BELLIED FLOWERPECKER       0.64      0.53      0.58        17
#          YELLOW BREASTED CHAT       0.77      0.77      0.77        22
#                YELLOW CACIQUE       0.79      0.88      0.83        17
#       YELLOW HEADED BLACKBIRD       1.00      0.89      0.94        18
#                    ZEBRA DOVE       0.85      0.94      0.89        18
#
#                      accuracy                           0.86      9388
#                     macro avg       0.86      0.85      0.85      9388
#                  weighted avg       0.86      0.86      0.86      9388
# /home/peter/PycharmProjects/DenseNet_bird_classification/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/peter/PycharmProjects/DenseNet_bird_classification/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/peter/PycharmProjects/DenseNet_bird_classification/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# <a id="conclusion"></a>
# ## Conclusion

# %% [markdown]
# In this project, I tackled the challenge of classifying birds into 525 different species using DenseNet and managed to achieve an 85% accuracy rate after over 60 training cycles. I took care to prepare our data properly and utilized callbacks to monitor the training process closely. TensorBoard was my go-to tool for keeping an eye on everything, and we adjusted the train/test/validation splits to ensure the model stayed sharp. Overall, DenseNet proved it's quite capable of handling large, complex datasets.
#
# The is definitely room for improvement, particularly for certain underperforming classes, by enhancing their images. Ultimately I decided to stay with provided dataset potentially this can be better compared with other models performance.
